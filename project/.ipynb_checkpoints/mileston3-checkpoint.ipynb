# %% [markdown]
# # ADA Project : Milestone 3 Notebook

# %% [markdown]
# In this notebook, we will introduce you to the dataset that we chose by locally importing a part of in, and store it in a dataframe. Hence, we will be able to have an insight on the work that we will perform on the full dataset.

# %%
import json
import re
from pyspark.sql import *
from pyspark import SparkContext, SQLContext
import numpy as np
import pandas as pd
from datetime import date, timedelta
import requests
from bs4 import BeautifulSoup
from dateutil.parser import parse
import csv
# %matplotlib inline

# %% [markdown]
# ## 1. Twitter dataset data collection, from cluster to dataframe
#
# In this section, we will make some operation with the help of Spark, to access, filter and export the useful tweets from the cluster to our computer.

# %% [markdown]
# ### A few words about what we noticed for our dataset
#
# First, the twitter dataset starts from year 2012.
# In the date section, the hour has been scaled, so that the tweet time is always relative to GMT+00. This will be of use when we will relate tweet dates and times with the Wikipedia dataframe.

# %% [markdown]
# ### 1.1 Filtering the useful tweets
#
# We start by declaring the Spark Context in order to make the link with the cluster. With Spark installed locally, we are able to query the cluster directly in the notebook.

# %%
sc = SparkContext()

# %%
text_file = sc.textFile("hdfs:///datasets/tweets-leon")

# %% [markdown]
# The idea of our filter is that we want to work with data that is already highly focused on our subject : terrorist  attacks. For the Milestone 2, we implemented a filter that considered different languages. Following the feedback from the TAs, we decided to stick with only English as the language of the tweets and the keywords, to go back to a **more simple, but more precise filter**. When a tweet is passed through the filter, we will compute the tweet score depending on its content and, if the score is high enough, select the tweet to be part of our dataframe.

# %% [markdown]
# **We define below a few helper functions that will be used for our inition filter :**

# %% [markdown]
# This function is the heart of the filter. Five lists are detailed, representing words of different importance.

# %%
def words_to_match():
    

    language = 'en'
    
    t1 = ['terror attack', 'terrorist attack','suicide bombing','mass shooting']



    t2 = ['suicide bomber','car bombing','drone bombing','mass execution','improvised explosive device','truck bomb','grenade attack','train bombing']


    t3 = [' ied', 'hijacking','genocide','bomb attack','vehicule attack','assasination','terrorism','weapon','knife','assault rifle','dead','deaths','died','injured','kill','plant','drive-by shooting','hostage','execution']


    hashtag = ['#prayfor','#terrorism','#terrorists','#terrorattack']

    malus_list = ['years ago','year ago', 'months ago','month ago','anniversary']
    
    l = [t1,t2,t3,hashtag,malus_list]
    
    return l

# %% [markdown]
# The below function computes the importance of a tweet by assigning specific weights to every tweet. The assignment is done by iterating on all interesting words, looking whether they occur in the tweet content. According to the word's affiliation to one of the lists, different weight are incremented. If the total weight of the tweet reaches the threshold value (here 1.0), the filter returns True.

# %%
def is_interesting(content,l):
    
    content = content.lower()
    
    lang = content[:2]
    
    
    weight=0.0
    
    
    
    for w in l[0]:
        if w in content:
            weight+=1.0

    for w in l[1]:
        if w in content:
            weight+=0.9

    for w in l[2]:
        if w in content:
            weight+=0.1
             
    for w in l[3]:
        if w in content:
            weight+=0.7
            
            
    for w in l[3]:
        if w in content:
            weight-=0.5
    
    return (weight >= 1)

# %% [markdown]
# We declare the variable `bds` to be the three filtering dictionnaries. It will serve as an input of our filtering function.

# %%
bds = words_to_match()

# %% [markdown]
# Next, we actually call spark by filtering the data in the cluster with our filter, to then take a subset of defined size. We proceed to write it to a text file for later use.

# %%
terrorism = text_file.filter(lambda t: is_interesting(t,bds)).take(10)

# %%
file_t = open('tweets_terror3.txt','w')
for item in terrorism:
    file_t.write("%s\n" % item)

# %%
terrorism[:5]
# Out:
# ['en\t345965752198762497\tSat Jun 15 18:07:17 +0000 2013\tSangyeH\tRT @AnnieSage: Unbelievable.... @thinkprogress: In the 6 months since Newtown, there have been FOURTEEN mass shootings http://t.co/yfClLGdx…',
#  'en\t345965794213117952\tSat Jun 15 18:07:27 +0000 2013\tSR_Brant\tRT @AnnieSage: Unbelievable.... @thinkprogress: In the 6 months since Newtown, there have been FOURTEEN mass shootings http://t.co/yfClLGdx…',
#  'en\t345968344391884800\tSat Jun 15 18:17:35 +0000 2013\tkiraababee\tRT @SweaterGawd: I cum faster than the fbi during a terrorist attack - 😳 shoulda kept that to yourself homie',
#  'en\t345968730020384768\tSat Jun 15 18:19:07 +0000 2013\tdrgauravn85\t@asma_rehman02 even your feeder USA is agreed your role in terrorist attacks',
#  'en\t345969984171823104\tSat Jun 15 18:24:06 +0000 2013\tWatchTVChannels\tQuetta Carnage: 23 killed in terrorist attacks http://t.co/CZm3wp7kki http://t.co/FLreqkpteK']

# %% [markdown]
# ### 1.2 Handling the filtered tweets
#
# #### Some issues we encountered:
#
# 1)    Tweets can countain retweet so many times the same tweet can appear with a retweet identification: `RT @<username>`
#     - Resolved by adding Frequency parameter for tweet that has been retweet
#     - Even tough we separeted the tweet from the retweet some of the tweets appears many time without the Retweet identification. It is still important to distinguish them and not count them many times since we reckon that simply copying a message or retweeting a message has less significance than creating it.
#
# 2)    Even if we remove the retweet, some tweets are still the same but have not the same length which can lead to count separetly the same tweet
#     - Resolved by putting a fixed max length to all tweet
#     - Or by testing if a string is in another (Complicated solution not adopted)

# %%
# Read the filtered tweets from the .txt files
tweets_raw = pd.read_csv(delimiter="\t",filepath_or_buffer='tweets_terr.txt', names=["lan","id","date", "user_name", "content"],encoding='utf-8',quoting=csv.QUOTE_NONE)

# %%
tweets_raw.head(5)
# Out:
#   lan            id                            date        user_name  \
# 0  en  3.459658e+17  Sat Jun 15 18:07:17 +0000 2013          SangyeH
# 1  en  3.459658e+17  Sat Jun 15 18:07:27 +0000 2013         SR_Brant
# 2  en  3.459683e+17  Sat Jun 15 18:17:35 +0000 2013       kiraababee
# 3  en  3.459687e+17  Sat Jun 15 18:19:07 +0000 2013      drgauravn85
# 4  en  3.459700e+17  Sat Jun 15 18:24:06 +0000 2013  WatchTVChannels
#
#                                              content
# 0  RT @AnnieSage: Unbelievable.... @thinkprogress...
# 1  RT @AnnieSage: Unbelievable.... @thinkprogress...
# 2  RT @SweaterGawd: I cum faster than the fbi dur...
# 3  @asma_rehman02 even your feeder USA is agreed ...
# 4  Quetta Carnage: 23 killed in terrorist attacks...

# %% [markdown]
# In this project, the id and user name of the tweet is useless, we keep therefore only the language, the date and the content of the tweet.

# %%
tweets_raw = tweets_raw.drop(axis= 1, labels=  ["id", "user_name"])
tweets_raw = tweets_raw.dropna()

# %% [markdown]
# The date countained in the tweets has been translated into `GMT` 0. So we do not have to worry about translating the date and can directly standarize with the dateutil.parser

# %%
#We parse the date to have a uniform 
tweets_raw["date"] = tweets_raw["date"].apply(lambda d: parse(d, ignoretz = True))

# %%
tweets = tweets_raw.copy()
tweets["retweet"] =  tweets["content"].map(lambda s : s[0:4] == "RT @") #Is it a retweet?

# %% [markdown]
# Here, we need to normalize our tweet to handle 1) and 2)

# %%
def remove_http(t):
    content = t.split()
    for w in content:
        
        if "http" in w:
            content.remove(w)
    return " ".join(content)



# Maximum length that we allowed to have in oder to not have different tweet

MAX_LEN = 140 - 15 - 10  # Limit of a tweet minus the maximum user name 
                         # and other charachter added when a retweet is created


def remove_retweet_and_cut(t):
    """
    Function that remove the RT @ in front of a tweet if it has been detected as a retweet, 
    And cut the tweet according to the MAX_LEN parameter
    """
    
    
    if(t["retweet"]): # We take advantage to uniform the tweets by the lower() function
        return ' '.join(t["content"].split()[2:])[0:MAX_LEN].lower()
    else :
        return t["content"][0:MAX_LEN].lower()
    

    
#Apply the functions we just created
tweets["content"] = tweets["content"].map(remove_http)
tweets["content"] =  tweets.apply(remove_retweet_and_cut, axis = 1)


#------------------------- Handling the frequency of a tweet ---------------------


# We create a dict to map the content and the frequency that a tweet with the same content occur.
freq_dict = dict(tweets.groupby("content")["lan"].count())


tweets = tweets.drop_duplicates(subset="content")


tweets["frequency"] = tweets["content"].map(lambda c : freq_dict[c])

# %% [markdown]
# We end up with a nice dataframe of the filtered tweets with the frequency of each tweets

# %%
tweets.sort_values(by="frequency", ascending=False).head()
# Out:
#        lan                date  \
# 423016  en 2015-01-12 00:36:17
# 352     en 2012-12-17 03:29:35
# 361528  en 2014-12-17 20:14:55
# 418277  en 2015-01-11 14:01:14
# 256112  en 2013-09-25 17:17:29
#
#                                                   content  retweet  frequency
# 423016  2,000 civilians killed in a terrorist attack i...     True       3006
# 352     here they are - all sixty-one mass shootings i...     True       1585
# 361528  just heard about the terrorist attack, my hear...     True       1330
# 418277  chanting &amp; applause in paris as huge crowd...     True       1242
# 256112  in 1962, the us government planned terrorist a...     True       1218

# %%
#Here are the single tweets
tweets.sort_values(by="frequency", ascending=True).head()
# Out:
#        lan                date  \
# 254900  en 2013-09-24 13:40:38
# 327762  en 2014-05-06 09:22:31
# 327763  en 2014-05-06 09:51:24
# 327764  en 2014-05-06 11:03:08
# 327765  en 2014-05-06 12:07:02
#
#                                                   content  retweet  frequency
# 254900  coming up. like bomb shelters here at home in ...    False          1
# 327762  people should go home for failing to prevent t...    False          1
# 327763  .@nikkiyanofsky, @un reports over 399 #priceta...    False          1
# 327764  @gasam101 would have called for the help of co...     True          1
# 327765  bombs planted near vaishali's polling station ...    False          1

# %% [markdown]
# We see below that the ratio of retweet is consequent.
# Indeed, roughly 1/3 of our filtered tweets have been retweeted.

# %%
tweets["retweet"].sum()/len(tweets.retweet)
# Out:
# 0.30587482267211957

# %%
grp_tweet = tweets.groupby("lan")

# %%
grp_tweet["content"].count()
# Out:
# lan
# de      1017
# en    319924
# es      1032
# fr       693
# it       842
# nl      1455
# Name: content, dtype: int64

# %% [markdown]
# We see that, not surprisingly, we have more english tweets than the other languages. Indeed english is the most common widespread language and spanish the second one.

# %%
tweets = tweets.drop(axis= 1, labels=  ["lan"])
tweets.to_csv("dataframe_terror.csv", index=False)

# %% [markdown]
# ## 2. Data from Wikipedia

# %% [markdown]
# In this part we scrape data from Wikipedia. We want to access the tables that register the terror attacks that happened at some point in the past. There are some Wikipedia articles (such as https://en.wikipedia.org/wiki/List_of_terrorist_incidents_in_January-June_2011) that do exactly that. The data is presented as tables, and all the articles that we need present data in this form.

# %%
# Simple map of month name to its number
month_to_int = {
    'January': 1,
    'February': 2,
    'March': 3,
    'April': 4,
    'May': 5,
    'June': 6,
    'July': 7,
    'August': 8,
    'September': 9,
    'October': 10,
    'November': 11,
    'December': 12
}

# Reversed map
int_to_month = {i: m for m, i in month_to_int.items()}

# %%
# The wikipedia URL that every article has in common
base_url = 'https://en.wikipedia.org/wiki/List_of_terrorist_incidents_in_'

# %% [markdown]
# We show all the articles that we are going to use to find the data

# %%
# All specific end of the wikipedia URL, along with the corresponding month numbers of the article
times = {}

for year in range(2011, 2015):
    # For years 2011 to 2014, the articles appear biyearly
    times.update({'January-June_' + str(year): list(range(1, 7))})
    times.update({'July-December_' + str(year): list(range(7, 13))})
    
for year in range(2015, 2018):
    # For years 2015 to 2017, the articles appear monthly
    for month, int_ in month_to_int.items():
        times.update({month + '_' + str(year): [int_]})
        
list(times.keys())
# Out:
# ['January-June_2011',
#  'July-December_2011',
#  'January-June_2012',
#  'July-December_2012',
#  'January-June_2013',
#  'July-December_2013',
#  'January-June_2014',
#  'July-December_2014',
#  'January_2015',
#  'February_2015',
#  'March_2015',
#  'April_2015',
#  'May_2015',
#  'June_2015',
#  'July_2015',
#  'August_2015',
#  'September_2015',
#  'October_2015',
#  'November_2015',
#  'December_2015',
#  'January_2016',
#  'February_2016',
#  'March_2016',
#  'April_2016',
#  'May_2016',
#  'June_2016',
#  'July_2016',
#  'August_2016',
#  'September_2016',
#  'October_2016',
#  'November_2016',
#  'December_2016',
#  'January_2017',
#  'February_2017',
#  'March_2017',
#  'April_2017',
#  'May_2017',
#  'June_2017',
#  'July_2017',
#  'August_2017',
#  'September_2017',
#  'October_2017',
#  'November_2017',
#  'December_2017']

# %%
def to_int(s):
    '''Returns the first integer found in s'''
    i = re.findall('\d+', s)
    return int(i[0]) if len(i) > 0 else float('NaN')

# %%
def to_date(s, year):
    '''Returns a date from the datetime library from a string like \'January 1\''''
    l = s.split(' ')
    return date(to_int(year), month_to_int[l[0]], to_int(l[1]))

# %%
def wiki_table_to_df(end_url, month_range, base_url=base_url):
    '''Creates a dataframe from the tables available in the wikipedia page'''
    print('Scraping for', end_url)
    r = requests.get(base_url + end_url) # Get request
    soup = BeautifulSoup(r.text, 'lxml') # Parse HTML
    wiki_tables = soup.findAll('table', {'class': 'wikitable sortable'}) # Get tables from the wikipedia page

    table = []

    for month_int, wiki_table in zip(month_range, wiki_tables):
        for row in wiki_table.findAll('tr'):
            elems = row.findAll('td') 
            if len(elems) != 0:
                interesting = [elem.text for elem in elems[:5]]
                 # First element is the day of the month, but we add the name of the month as well in front of it
                interesting[0] = int_to_month[month_int] + ' ' + interesting[0]
                table.append(interesting)
                
    df = pd.DataFrame(table, columns=['date', 'type', 'deaths', 'injuries', 'location'])
    df.date = df.date.apply(lambda s: to_date(s, end_url[-4:])) # Translate the date with the year defined by the end_url arg
    df.deaths = df.deaths.apply(to_int) # Map death number to int
    df.injuries = df.injuries.apply(to_int) # Map injuries number to int
    
    return df

# %%
dfs = []

# Get a DataFrame for every article from 2011 to 2017
for time, month_range in times.items():
    dfs.append(wiki_table_to_df(time, month_range))
    
df = pd.concat(dfs)
print('We have {} registered attacks from January 1st, 2011 up to today (November 28th, 2017)'.format(df.shape[0]))
# Out:
# Scraping for January-June_2011
# Scraping for July-December_2011
# Scraping for January-June_2012
# Scraping for July-December_2012
# Scraping for January-June_2013
# Scraping for July-December_2013
# Scraping for January-June_2014
# Scraping for July-December_2014
# Scraping for January_2015
# Scraping for February_2015
# Scraping for March_2015
# Scraping for April_2015
# Scraping for May_2015
# Scraping for June_2015
# Scraping for July_2015
# Scraping for August_2015
# Scraping for September_2015
# Scraping for October_2015
# Scraping for November_2015
# Scraping for December_2015
# Scraping for January_2016
# Scraping for February_2016
# Scraping for March_2016
# Scraping for April_2016
# Scraping for May_2016
# Scraping for June_2016
# Scraping for July_2016
# Scraping for August_2016
# Scraping for September_2016
# Scraping for October_2016
# Scraping for November_2016
# Scraping for December_2016
# Scraping for January_2017
# Scraping for February_2017
# Scraping for March_2017
# Scraping for April_2017
# Scraping for May_2017
# Scraping for June_2017
# Scraping for July_2017
# Scraping for August_2017
# Scraping for September_2017
# Scraping for October_2017
# Scraping for November_2017
# Scraping for December_2017
# We have 4697 registered attacks from January 1st, 2011 up to today (November 28th, 2017)

# %% [markdown]
# Here is what some of the entries of the final result look like

# %%
df.iloc[[0, 56, 1033, -1]]
# Out:
#           date                    type  deaths  injuries  \
# 0   2011-01-01         Suicide bombing    21.0      97.0
# 56  2011-02-13                    Raid     7.0       5.0
# 37  2014-11-18  Shooting, Melee attack     5.0       7.0
# 48  2017-12-17         Suicide bombing     1.0       5.0
#
#                           location
# 0                Alexandria, Egypt
# 56          Zamboanga, Philippines
# 37               Jerusalem, Israel
# 48  Kandahar province, Afghanistan

# %% [markdown]
# Finally, we want to separate the location into a city, and a country, if applicable. This separation will be very useful for the matching of the attacks with our tweet dataset. To do so, we define some helper function :

# %%
def get_city(location):
    if ',' in location :
        city = location.split(', ',1)[0]
        return city
    else : 
        return "Unknown"
    
def get_country(location):
    if ',' in location :
        country = location.split(', ')[-1]
        return country
    else : 
        return location


words_to_remove_1 = ['near', 'and', 'other', 'cities', 'between','b','at','least','of','old','in','de','various']
words_to_remove_2 = ['district', 'province', 'region','outskirts','department','state','central','east','far','north','village','heights','cercle','junction','hills','city','island','state','agency','lake','route','south','town']
signs_to_remove = [',', '"','/','(',')']
#aussi enlever les numeros


#liste des mots a GARDER : si ca contient un de ces mots, garder toute la string
to_keep_with_all = ['abu','al','del','beit','beni','bir','el','ein','las','la','les','los','new','san','tel','tal']

# %%
def is_long(x):
    l = len(x.split())
    
    if l>1:
        return x
    else: 
        return float('NaN')

#```df['city'].map(is_long).dropna().sort_values().to_frame().drop_duplicates('city').to_csv('different_cities.csv',index = False)

# if ville_connue in df['city] -> replace

# %%
df['city'] = df['location'].map(get_city)
df['country'] = df['location'].map(get_country)
df["type"] = df["type"].fillna("UnkownType")
df = df.drop(axis= 1, labels=  ["location"])
df.to_csv('attacks.csv', index = False)

# %% [markdown]
# We now have a useful and clean dataset of all terrorist attacks listed on wikipedia. The next step will be to analyze this data first on its own, and then coupled with the twitter dataset that we defined before.

# %% [markdown]
# ## 3. Making sense of the Data

# %% [markdown]
# In this section, we will detail our analysis in an attempt to answer to the fundamental questions of our project : which part of the world is more hit by terrorist events, and how can we compare the real impacts (deaths, injured) of such attacks with the reaction on the social media sphere (number of tweets, relevance on attacks).
#
# As explained a few cells below next to the corresponding code, we will **focus on a time period between January 2011 and January 2016** (which is the timestamps of the oldest and most recent tweets in the database) for the rest of our analysis. The results, displays and analysis will therefore be related to this specific time period of **five years**. This period is according to us long enough to advance certain hypothesis, and it has also been marked by the rise and fall of many different terrorist groups that shaped a big part of the geopolitics of today.

# %%
ls
# Out:
# 01 - Pandas and Data Wrangling/ project/
# 02 - Data from the Web/         terr.txt
# 03 - Interactive Viz/           tweets.txt
# 04 - Applied ML/                tweets_terror2.txt
# README.md                       tweets_terror3.txt
# mileston3.ipynb

# %%
tweets = pd.read_csv("dataframe_terror.csv", parse_dates=[0])
terror = pd.read_csv('attacks.csv', parse_dates=[0], encoding="utf-8")
terror["type"] = terror["type"].fillna("UnkownType")

# %%
print(len(tweets))
tweets.head()
# Out:
# 324963
#                  date                                            content  \
# 0 2013-06-15 18:07:17  unbelievable.... @thinkprogress: in the 6 mont...
# 1 2013-06-15 18:17:35  i cum faster than the fbi during a terrorist a...
# 2 2013-06-15 18:19:07  @asma_rehman02 even your feeder usa is agreed ...
# 3 2013-06-15 18:24:06  quetta carnage: 23 killed in terrorist attacks...
# 4 2013-06-15 18:36:29     quetta carnage: 23 killed in terrorist attacks
#
#    retweet  frequency
# 0     True          2
# 1     True          1
# 2    False          1
# 3    False          1
# 4    False          2

# %%
print(len(terror))
terror.head()
# Out:
# 4703
#         date             type  deaths  injuries                  location  \
# 0 2011-01-01  Suicide bombing    21.0      97.0         Alexandria, Egypt
# 1 2011-01-04    Assassination     1.0       0.0       Islamabad, Pakistan
# 2 2011-01-04          Bombing     4.0      26.0            Abuja, Nigeria
# 3 2011-01-07       Kidnapping     9.0       NaN                     Niger
# 4 2011-01-07  Suicide bombing    17.0      23.0  Spin Boldak, Afghanistan
#
#           city      country
# 0   Alexandria        Egypt
# 1    Islamabad     Pakistan
# 2        Abuja      Nigeria
# 3      Unknown        Niger
# 4  Spin Boldak  Afghanistan

# %%
terror.type.unique()
# Out:
# array(['Suicide bombing', 'Assassination', 'Bombing', 'Kidnapping',
#        'Ambush', 'Violence, fighting', 'Shooting, riot', 'Car bomb',
#        'Shooting', 'Shooting/Targeted killing', 'Roadside bombings',
#        'Shooting/Execution', 'Car bombing', 'Shooting/Raid',
#        'Suicide car bombing', 'Piracy/Hijacking', 'Bombs',
#        'Raid/Piracy/Hijacking', 'Improvised explosive device',
#        'Car bombings', 'Suicide bombings', 'IED', 'Killing', 'Car Bomb',
#        'Riots', 'Violence', 'Armed assault', 'Raid', 'Military attack',
#        'Airstrike', 'Suicide bombing/Roadside bombing', 'Bombings',
#        'Shooting, raid', 'Drone bombing', 'Bomb', 'Roadside bombing',
#        'Shootings', 'Execution', 'Shootings/Targeted Killings',
#        'Explosion', 'Hostage Crisis', 'IED, Shooting',
#        'Targeted killings/Shootings', 'Clashes', 'Bombings/Shootings',
#        'Suicide bombing/Shooting/Bombing', 'Shooting/Bombing',
#        'Suicide bombings/Shootings', 'Grenade attack', 'Car bombs',
#        'Bombings, shootings, hostage taking - see PNS Mehran attack',
#        'Suicide bombing, shootings', 'suicide bombing, car bombing, IED',
#        'Bombing \\ Suicide bombing',
#        'Bombing \\ Suicide Bombing \\ Shooting', 'Shooting \\ Bombing',
#        'Shooting, Bombing', 'Shooting, IED', 'Suicide bombing, Bombing',
#        'Suicide bombing, Shooting', 'Suicide bombing, Car bombing',
#        'Drone strike, Bombing', 'Shooting, Bombing, IED',
#        'Car bombing, Suicide bombing', 'Bicycle bombing',
#        'Suicide attacks', 'Various', 'Shooting assassination',
#        'Ambush, shooting', 'Bombings, shootings', 'Bombings, Car bombs',
#        'Shooting assassination, suicide bombing, siege',
#        'Bombing, stabbing', 'Shooting and rockets', 'Shooting, bombing',
#        'Bombing/shooting', 'Suicide bombing/shooting',
#        'Suicide bombings, shootings', 'Suicide bombing, car bomb',
#        'IED, shootings', 'Hostage taking', 'Carbombing, stabbing', 'Arson',
#        'Rocket-propelled grenade attack', 'Car bomb, Suicide bombings',
#        'Rocket attack', 'Suicide bombings, car bombs, IEDs',
#        'Raid, shootout', 'Raids', 'Ambush, shooting, bombing', 'Air raids',
#        'Tribal conflict', 'Interception and shooting', 'Rocket',
#        'Bicycle bomb', 'Police firing', 'Shooting/Bombing/Suicide attack',
#        'Drive-by Shooting', 'Car Bombing', 'Parcel bomb', 'Murder-suicide',
#        'Police shooting', 'Suicide and car bombings',
#        'Suicide bombing, bombing', 'Shootings, sticky bombs, IEDs',
#        'Shootings, bombings', 'Suicide bombings, bombings',
#        'Shootings, mortar attacks, IEDs', 'Firefight',
#        'Shootings, car bombs, suicide bombings, IEDs',
#        'Shootings, suicide bombings',
#        'Shootings, grenade attacks, kidnappings',
#        'Suicide bombing, IEDs, car bombing',
#        'Suicide bombings, car bombings', 'Car bombings, IEDs',
#        'Shooting, kidnapping', 'Suicide bombing, IED',
#        'Shootings, car bombs, IEDs',
#        'Suicide bombing, shootings, bombings',
#        'Shootings, bombings, suicide bombing', 'Motorcycle bomb',
#        'Suicide car bombings', 'Suicide Bombing',
#        'Suicide bombings, car bombs, shootings, IEDs',
#        'Bombings, attempted jailbreak', 'Suicide car bombing, bombing',
#        'Stabbings', 'Gunbattle', 'Suicide \\ Car bombing (unconfirmed)',
#        'Shootings, assassinations', 'Car bomb, suicide bombing',
#        'Bombing, kidnappings, firefight', 'Car bombing, reprisal killings',
#        'Petrol bomb', 'Shootings, robberies', 'Motorcycle bomb, IED',
#        'Suicide bombings, car bombs, shootings', 'Mortar attack',
#        'Firefight, aerial bombardment', 'Ambushes',
#        'Suicide bombings, firefights, sieges',
#        'Car bombs, Suicide bombings, IEDs', 'Ambush, mortar attack',
#        'Roadside bomb', 'Car bombing, shootings', 'Smoke Bombings',
#        'Suicide bombing, shootings, IEDs', 'School Bombing',
#        'Car bombings, bombings', 'Car bombings, shootings',
#        'Shootings, hostage crisis', 'Suicide bombings, shooting',
#        'Airplane hijacking', 'Bombing, shootings',
#        'Car bombings, suicide bombings, shootings', 'Serial bomb blasts',
#        'Suicide bombing, IED, shootings', 'Car bombing, shooting',
#        'Truck bomb, shootings', 'Shootings, IED',
#        'Suicide bombings, IED, shootings', 'Suicide bombing, shooting',
#        'Air strike', 'Suicide bombing, mortar attack', 'Terror attack',
#        'IED, shooting', 'Shooting, arson', 'Shooting, grenade attack',
#        'Car bombs, shootings', 'Massacre',
#        'Suicide bombings, IEDs, shootings', 'Shooting ambush',
#        'Attempted Bombing', 'Suicide bombing, IEDs', 'Bombing, shooting',
#        'Bombings, IEDs', 'Bombings, IEDs, shootings',
#        'Suicide bombing, massacre', 'Car bombing, IED',
#        'Suicide bombings, bombing', 'Rocket attacks',
#        'Shooting, hostage crisis', 'Suicide truck bombing', 'Bombing plot',
#        'Car bombings, Shootings', 'Assault', 'Stabbing', 'Knife attack',
#        'Shootout', 'IED, ambush', 'Prison break', 'Shootings, stabbings',
#        'Mass murder', 'Suicide car bombing, shooting',
#        'Suicide and other bombings, shootings', 'Mortar bomb',
#        'Suicide bombing, bombings', 'various',
#        'Assassination, car bomb, other bombs', 'Suicide truck bomb',
#        'Suicide car bomb', 'Car and other bombs', 'Suicide bomb and bomb',
#        'Ambush and firefight', 'Bombings, ambush, shootings',
#        'Suicide bomb', 'Vehicle bomb', 'Raid/shooting',
#        'Bombings, shootings, suicide bomb', 'Missile', 'Shooting, bomb',
#        'Chemical attack', 'Car Bombing, suicide-bombing',
#        'Clashes, arson and hostage-taking', 'Truck bomb, shooting',
#        'Ambush, Shooting', 'Car bombing, suicide-bombing, clashes',
#        'Clashes, hostage-taking', 'Hostage-taking',
#        'Shooting, suicide bombing', 'Car attack', 'Murder, Kidnapping',
#        'Grenade Attack',
#        'Hostage taking, suicide car bombing and shooting', 'Truck bombing',
#        'Series of explosions', 'Suicide car bomb assassination',
#        'Double roadside bombing', 'Series of car bombings',
#        'Train bombing', 'Suicide bombing, gun attack',
#        'Remote controlled bicycle bombing',
#        'Truck bombing, other explosions', 'Double car bombing',
#        'Double suicide car bombing',
#        'Gun attack, hostage taking, suicide bombing', 'Bus bombing',
#        'Attack', 'Double car bomb', 'Car and suicide bombings',
#        'Triple car bombing and suicide bombing', 'Series of car bombs',
#        'Double bombing', 'Grenade and gun attack', 'Village attack',
#        'Roadside bus bombing', 'Quadruple car bombing',
#        'Double suicide bombing', 'Suicide car bombing, gun attack',
#        'Car and motorcycle bombings', 'Bombing, gun attack',
#        'Triple bombing', 'Knife assault on train station', 'Gun attack',
#        'Suicide mini-bus bombing', 'Sticky bomb attacks',
#        'Gun and vehicular attack', 'Triple car bombing',
#        'Suicide motorcycle bombing', 'Suicide bombings, gun attack',
#        'Roadside and car bombings', 'Landmine', 'Pillage', 'Bomb attacks',
#        'Bombing, assassination', 'Suicide truck bombings', 'UnkownType',
#        'Skirmish between rebels and government', 'Standoff/shootout',
#        'Suicide bombing, shootout, raid',
#        'Kidnapping, followed by torturing and murdering the victim',
#        'Airliner shootdown', 'Grenade attack, bombing, shooting',
#        'Vehicular assault', 'Melee attack', 'Melee assault', 'Grenade',
#        'Shooting, Melee attack', 'Bombing, Melee attack',
#        'Shooting, Ambush', 'Shooting, Hostage taking',
#        'Suicide bombing, Mass shooting,', 'Vehicular attack',
#        'Mass shooting', 'Hostage crisis', 'Artillery', 'Melee Attack',
#        'Beheading', 'Mass shooting, Bombing',
#        'Vehicular assault, Melee attack', 'Shooting, hostage taking',
#        'Hostage taking, Shooting', 'Mass shooting, arson',
#        'Shooting,bombing', 'Suicide bombing, hostage taking',
#        'Unarmed Assault', 'bombing', 'Car bomb, Shooting',
#        'Massacre, Suicide bombing, Hostage-taking',
#        'Bombing, Mass shooting', 'Bombing, Beheading', 'Shelling',
#        'Spree shooting', 'Arson, Vandalism', 'Melee weapon', 'car bomb',
#        'Shooting Melee attack', 'Chemical', 'Suicide bombing and car bomb',
#        'Stone-throwing', 'Mass stabbing', 'Bombing, Suicide Bombing',
#        'Raid, arson', 'Raid, kidnapping, arson', 'Melee attack, Shooting',
#        'Bombing, Stabbing', 'Melee attack, shooting',
#        'Suicide bombing, car bombing, shooting', 'Raid, Arson',
#        'Shooting Hostage-taking',
#        'Suicide bombing, hostage taking, shooting', 'Car bombing, raid',
#        'Shooting, car bombing', 'Suicide-bombing', 'suicide bombing',
#        'Executed', 'Crushed', 'Suicide bomber',
#        'Suicide bombing and attack', 'Bombing, rocket, clashes',
#        'Suicide bombings, shoot-out', 'Siege',
#        'Mass shooting, arson, siege', 'Beheaded', 'Poisoning, shooting',
#        'Clash', 'beheading', 'Shooting, melee attack',
#        'Truck bomb, mortar fire', 'Melee attack,bombing', 'Land mine',
#        'Attempted arson', 'Suicide bombing, bomb and shooting',
#        'Car bomb, rocket attack', 'Bomb, shooting', 'Clashes, raid',
#        'Vehicular attack, shooting', 'Bombing, Rocket attack',
#        'Mortar attack, shooting', 'Car bombing, shooting, raid', 'Burning',
#        'Unknown', 'Motorbike bombing', 'Mortar Attack', 'Falling',
#        'Freezing', 'Drowning', 'Suicide Car Bombings',
#        'Attack, suicide car bombing', 'Rocket attack, chemical attack',
#        'Suicide car bombing, suicide motorbike bombing',
#        'Shooting and bombing', 'Gas attack', 'Mass execution, genocide',
#        'Explosive devices', 'Burying', 'Attacks', 'Stoning',
#        'Rocket attack, mortar attack',
#        'Suicide and car bombings, shooting', 'Chemical execution',
#        'Explosive device', 'Multiple attacks', 'Machete attack',
#        'Shooting, attack', 'Execution and shelling',
#        'Kidnapping and execution', 'Suicide Bombings',
#        'Suicide car bombing, hostage-taking',
#        'Suicide bombing and shooting', 'Spree shooting, shootouts',
#        'Mass execution', 'Execution/shooting', 'Cut down',
#        'Kidnapping, shooting, and execution', 'Clash, bombing',
#        'Shooting and shelling', 'Melee attack, hostage-taking',
#        'Suicide attack', 'Suicide bombing and execution', 'Crucifying',
#        'Shooting and stabbing', 'Shooting and Kidnapping',
#        'Shooting and burning', 'Shooter',
#        'Suicide bombing and Rocket attack', 'Shooting, hostage-taking',
#        'Rockets attack', 'Shooting, machete attack',
#        'Suicide bombing, raid', 'Mortar attack, suicide bombing',
#        'Mortar attacks and other attacks', 'Shootdown',
#        'Counter-terrorism raid', 'Bombing, Shooting',
#        'Suicide bombing, Attack', 'Executions', 'Vehicular Assault',
#        'Suicide bombing and other bombings', 'Land Mine',
#        'Melee Attack, hostage-taking', 'Suicide bombing, other attacks',
#        'Bombing, Mortar Attack, Suicide bombing',
#        'Shooting, Suicide bombing', 'Truck bombing, shooting',
#        'Car suicide bombing', 'Execution and other attack', 'Execuction',
#        'Shooting, shelling', 'Shooting, kidnapping, execution',
#        'Shooting and suicide bombing', 'Attempted bombing',
#        'Arson, shooting, abduction', 'Explosive attack',
#        'Shooting, abduction', 'Attempted Bombing, stabbing',
#        'Shooting/attack', 'Arson attack', 'Rockets attack, bombings',
#        'Roadside Bombing', 'Bombings, shootout', 'Explosion, shooting',
#        'Roadside Bomb', 'Drone', 'Shooting, suicide Bombing',
#        'Shooting,suicide bombing', 'Melee attack, attempted bombing',
#        'Shooting, suicide bombings', 'Suicide Car Bombing',
#        'Hostage taking, shooting, suicide bombing', 'Executions,shooting',
#        'Kidnapping, shooting', 'Bombing, Execution', 'Rocket Attack',
#        'Vehicular Attack', 'Car bombing, bombings', 'Execution, shooting',
#        'Shoot-down', 'Land mine, shooting', 'Shooting, bombing, arson',
#        'Sabotage', 'Roadside bomb, shooting', 'Shooting, Mortar attack',
#        'Vehicular assault, stabbing', 'Shooting, mortar attack',
#        'Car bombing, suicide bombing', 'Strobe GIF',
#        'Vehicular attack, stabbing, and shooting', 'Hijacking',
#        'Shooting, stabbing', 'Vehicular attack, suicide bombing',
#        'Jailbreak, shootout', 'Attempted suicide bombings',
#        'Suicide car bombing, Car bombing', 'Suicide bombings, Car bombing',
#        'Shooting, attempted suicide bombings', 'Stabbing,',
#        'Shooting, Attempted kidnapping', 'Bombing, kidnapping',
#        'Shooting, Raid', 'Attempted suicide bombing', 'Bombing, Ambush',
#        'Bombing,\nshooting', 'Suicide car bombings,\nshooting',
#        'Executions, kidnapping', 'Attempted attack', 'Arson, Bombing',
#        'Attacks and kidnapping', 'Airstrikes', 'Assassination, kidnapping',
#        'Stabbing, melee', 'Landmine, Shooting', 'Attack, Shooting',
#        'Petrol bombing', 'Shooting, execution', 'Attempted Assassination',
#        'Suicide car bomb, ambush', 'Shooting, Clash',
#        'Suicide car bombing, suicide bombing', 'Assault, shooting',
#        'Attempted Suicide Bombing', 'Sucide bombings',
#        'Vehicle attack, stabbing', 'Roadside Bombing, Shooting',
#        'Shooting, assassination', 'Shooting, Assassination',
#        'Suicide bombing, bombings, shooting',
#        'Suicide Car Bombing, Shooting', 'Shooting, Suicide bombings',
#        'Attempted shooting', 'melee attack', 'Execution, Kidnapping',
#        'Suicide car bombing, Shooting', 'Shooting, Kidnapping',
#        'Shooting, Bombings', 'Shooting, Suicide bombing, Hostage-taking',
#        'Shooting, Armed attack', 'Kidnapping, Execution',
#        'Vehicular attack, Stabbing', 'Shooting, suicide Bombings',
#        'Shooting, clashes', 'Kidnapping, execution',
#        'Kidnapping, stabbing', 'Jailbreak',
#        'Suicide car bombing, shooting, hostage taking',
#        'Stabbing, shooting',
#        'Attempted suicide bombing, Shooting, Melee attack',
#        'Assassination, Shooting', 'Assassination, Kidnapping',
#        'Hijacking, Grenade Attack', 'Suicide bombings, grenade',
#        'Suicide Car Bombing, Attempted Car Bombings', 'Clashes, bombing',
#        'Car bombing, bombing', 'Attempted stabbing',
#        'Kidnapping, executions', 'Suicide bombing, car bombing',
#        'Bombing, shelling', 'Sniper Attack', 'Assault,Shooting',
#        'Vehicular attacks, Stabbings, Bombings',
#        'Shooting, stabbing, arson', 'Shooting, arson, kidnapping',
#        'Suicide attacks, shooting', 'Beheadings', 'Car bombing, Shooting',
#        'Rocket attack, bombing', 'Bombing, Arson', 'Sucide car bombing',
#        'Stabbing, vehicular attack', 'Attempted truck bombing',
#        'Car bombings, Bombings, Shootings', 'Possibly bombing, shooting',
#        'Shootings, Attacks', 'Vehicular attack, Attempted stabbing',
#        'Shootings, Grenade attacks, Raid', 'Bombing, Shootings',
#        'Bombing, Suicide car bombing', 'Rocket, bombing', 'Rockets',
#        'Bombing, Car bombing', 'Shelling, Explosion',
#        'Attempted suicide attack (pipe bomb partially detonated)',
#        'Stabbing, Attempted suicide bombing', 'Shooting, Execution'], dtype=object)

# %%
min_date = max(tweets.date.min(), terror.date.min())
max_date = min(tweets.date.max(), terror.date.max())

tweets = tweets[(tweets["date"]>min_date) & (tweets["date"]<max_date )]
terror = terror[(terror["date"]>min_date) & (terror["date"]<max_date )]

print("tweets len = "+str(len(tweets)))
print("tweets len = "+str(len(terror)))
# Out:
# tweets len = 319682
# tweets len = 1579

# %%
 ## The scores: 
def date_score(dtweet, dattack):
    diff = (dtweet - dattack).days
    
    alpha = 0.55
    
    if diff < 0 :
        return -np.Inf
    
    else :
        if 0 <= diff and diff < 4:
            return 0.79
            
        return 0.79 / (alpha *(diff-4) + 1)

def match_attacks(t, terror):
    #print(t)
    to_keep_with_all = ['abu','al','del','beit','beni','bir','el','ein','las','la','les','los','new','san','tel','tal']
    
    overall_score = 0
    overall_index = -1
    
    delta = timedelta(31)
    
    #We won't worry the case where the attack date is greater than the date of the tweet
    sub_terror = terror[(terror["date"]<t["date"]) & (terror["date"]>t["date"]-delta) ]
    
    content = t["content"].split()
    
    # List related to death:
    death_sem = ["die", "death", "dead", "kill"]
                       
    # List related to injured
    injured_sem = ["injure", "hurt", "wound", "harm", "damage"]
    
    # List of attacks that can easily be missclassified from 
    # a terrorist attack (reduce the type score see bellow)
    common_attack = ["attacks", "shooting", "bombing", "bombs"]
    
    
    # List of malus words that doesn't fit in the context of a terrorist attack
    malus_word = ["great", " happy", " friend"]
    
    
    malus = False
    # Malus word 
    for w in malus_word:
        if w in t["content"]:
            
            malus = True
            break
    
    #For ecach event we will compute the hypothetic score matching relating to a particular attack
    for index, attack in zip(sub_terror.index,sub_terror.get_values()):


        # extracting the attack parameters
        dattack, type_attack, death, injured, _ ,city, country = attack
        
        sda, sde, si, sci, sco, st = [0, 0,0,0,0,0]
        #
        score = date_score(t["date"], dattack )
        sda = score
                       
        #If the tweet countains the exact number of death we already consider as acceptable
        if(not np.isnan(death)):
            if(str(int(death)) in content) or (str(int(death-1)) in content): #We also consider death - 1 in case the killer killed himself wikipedia count every killed whereas the tweets basically don't count it        
                #print("Yo")
                for w in death_sem:
                    #print(w)
                    if w in t["content"]:
                        
                        sde=0.24 * len(str(int(death-1)))
                        
                        #It's very easy to match number with one digit, less with 2 ... ect so:
                        score +=0.24 * len(str(int(death)))
    

        #If the tweet countains the exact number of injured we already consider as acceptable
        if(not np.isnan(injured)):
            if((str(int(injured)) in content)):
                
                for w in injured_sem:
                    if w in t["content"]:
                        
                        si=0.24 * len(str(int(injured))) 
                        score +=0.24 * len(str(int(injured))) 
                        #print("injured score = "+str(0.45 * len(str(int(injured)))))

        #If the tweet countains the city of the attack we already consider as acceptable

        if(city.lower() in t["content"]):
            score += 0.8
            sci = 0.8
            #print("city score = "+str(0.7))
            
        #If the tweet countains the country of the attack we don't consider as acceptable,
        #but we increase the score
        if(country.lower() in t["content"]):
            score += 0.6
            sco = 0.6
            #print("country score = "+str(0.5))

        
        if(type_attack.lower() in t["content"] ):
            
            in_ = False
            
            for w in common_attack:
                
                if (type_attack.lower() in w):
                    in_ = True
                    st += 0.1
                    score += 0.1
                    #print("attack score = "+str(0.1))
                    break
            
            if(not in_):
                st += 0.5
                score += 0.5

        if(malus):
            score -=0.3
        
        
        # used for debugging       
        #print("tweet ="+str(t.name)+" index = "+str(index)+ " score="+str(score)[:4] +
         #     " sda="+str(sda)[:4]+" sde="+str(sde)+" si="+str(si)+" sci="+str(sci)+" sco="+str(sco)+" st="+str(st))             
        
        # Now we check if the previous best score is lower than the current one
        if(overall_score < score):
            overall_score = score
            overall_index = index
    
    if(overall_score <1 ):
        return -1
    
    else:
        return overall_index

# %%
N = 243896
tu = tweets.copy()

# %time tu["related_attack"] = tu.apply(lambda t: match_attacks(t, terror) , axis = 1)

# %%
tu
# Out:
#                       date                                            content  \
# 243876 2015-01-08 19:59:57  paris attack: europe's far-right gets media sp...
# 243877 2015-01-08 19:59:57  holder heading to paris for meetings after ter...
# 243878 2015-01-08 20:00:06  tens of thousands rally against islamic terror...
# 243879 2015-01-08 20:00:22  #technos eiffel tower goes completely dark to ...
# 243880 2015-01-08 20:00:50  @thoseeightboys i am charlie. it's to remember...
# 243881 2015-01-08 20:01:13  campaigner-in-chief' silent on paris terror at...
# 243882 2015-01-08 20:01:25  after every militant islamist terrorist attack...
# 243883 2015-01-08 20:02:13  holder heading to paris for meetings after ter...
# 243884 2015-01-08 20:02:22  eiffel tower goes completely dark to honor vic...
# 243885 2015-01-08 20:02:27  a message from israeli prime minister sending ...
# 243886 2015-01-08 20:02:37  mashable &gt; eiffel tower goes completely dar...
# 243887 2015-01-08 20:02:55  islamic terror attacks in \n\nboston \nbrussel...
# 243888 2015-01-08 20:03:09  rip to the dozen men and women that were bruta...
# 243889 2015-01-08 20:03:14  heartbreaking “@tzvalero: “@abc: lights of the...
# 243890 2015-01-08 20:03:22  statement regarding the terrorist attack on th...
# 243891 2015-01-08 20:03:38  watch the eiffel tower's lights go out in memo...
# 243892 2015-01-08 20:03:48  lights of the eiffel tower in paris dimmed in ...
# 243893 2015-01-08 20:04:01  paris' response to the terror attacks via soli...
# 243894 2015-01-08 20:04:13  what's up with these pro-muslim hashtags right...
# 243895 2015-01-08 20:04:16  jon stewart takes on the terrorist attack agai...
# 243896 2015-01-08 20:04:22  [ut news] a timeline of terror in paris: a clo...
# 243897 2015-01-08 20:05:00  #pyd/#ypg statement regarding the terrorist at...
# 243898 2015-01-08 20:05:05  every time there's a terror attack or mass sho...
# 243899 2015-01-08 20:05:17  #m1blog eiffel tower goes completely dark to h...
# 243900 2015-01-08 20:05:23  all terror attacks are backlash? what was 26/1...
# 243901 2015-01-08 20:05:54  .@leelajacinto tells @huffpostlive\nthat the f...
# 243902 2015-01-08 20:05:55  @stationox11 what a crazy, a shame her movemen...
# 243903 2015-01-08 20:06:05  @rykov @dimusik63 this cartoon charlie hebdo d...
# 243904 2015-01-08 20:06:12  terrorism didnt only strike in paris 2day but ...
# 243905 2015-01-08 20:06:25  'je suis charlie': paris gathers after terror ...
# 243906 2015-01-08 20:06:45  eiffel tower goes completely dark to honor vic...
# 243907 2015-01-08 20:07:07  i like terror attack on http://t.co/9oucuyldvy...
# 243908 2015-01-08 20:07:21  @ferialhaffajee i deplore the terror attack on...
# 243909 2015-01-08 20:08:02  who had this terrorist attack cannot be muslim...
# 243910 2015-01-08 20:08:07  @jshastun @combattantru @alendales @_iride vet...
# 243911 2015-01-08 20:09:09  eiffel tower goes completely dark to honor vic...
# 243912 2015-01-08 20:09:43  ahmed merabet: police officer executed in ‘cha...
# 243913 2015-01-08 20:09:48              terror attack used to push pc culture
# 243914 2015-01-08 20:10:08  it was an islamic terror attack, dammit: three...
# 243915 2015-01-08 20:10:23  the lights are dimmed on the eiffel tower to p...
# 243916 2015-01-08 20:11:01  “@skynewstonight: watch the eiffel tower's lig...
#
#         retweet  frequency  related_attack
# 243876    False          1            1077
# 243877     True          1            1077
# 243878    False          1              -1
# 243879    False          1            1077
# 243880    False          1            1077
# 243881    False          1            1077
# 243882    False          1              -1
# 243883    False          1            1077
# 243884    False          1            1077
# 243885    False          1            1077
# 243886    False          1            1077
# 243887    False          1              -1
# 243888    False          1            1077
# 243889     True          3              -1
# 243890     True          4              -1
# 243891    False         19            1077
# 243892     True          6            1077
# 243893    False          1            1077
# 243894     True          2              -1
# 243895    False          1              -1
# 243896    False          1            1077
# 243897    False          1              -1
# 243898     True          1            1077
# 243899     True          1            1077
# 243900    False          1              -1
# 243901     True          1              -1
# 243902    False          1              -1
# 243903    False          2              -1
# 243904     True          1            1076
# 243905    False          1            1077
# 243906    False          1            1077
# 243907    False          1              -1
# 243908    False          1              -1
# 243909    False          1              -1
# 243910    False          1            1077
# 243911     True          1            1077
# 243912    False          1              -1
# 243913    False          2              -1
# 243914    False          1              -1
# 243915    False          1            1077
# 243916    False          1            1077

# %%
compare_(243891, 1076)
# Out:
# watch the eiffel tower's lights go out in memory of those killed in terror attacks on paris #skynewstonight
# ------------------------------------
# date                                       2015-01-08 20:03:38
# content      watch the eiffel tower's lights go out in memo...
# retweet                                                  False
# frequency                                                   19
# Name: 243891, dtype: object
# ------------------------------------
# date        2015-01-07 00:00:00
# type                   Car bomb
# deaths                       37
# injuries                     66
# location          Sana'a, Yemen
# city                     Sana'A
# country                   Yemen
# Name: 1076, dtype: object

# %%
terror[440-50:761+5]
# Out:
#           date                                   type  deaths  injuries  \
# 712 2013-07-14                    Bombings, shootings    33.0     100.0
# 713 2013-07-15                               Bombings     NaN       NaN
# 714 2013-07-20                                Clashes    21.0       6.0
# 715 2013-07-20                    Bombings, shootings    63.0      19.0
# 716 2013-07-21                           Prison break    50.0     500.0
# 717 2013-07-21                             Kidnapping     0.0       1.0
# 718 2013-07-23                                Clashes     5.0       4.0
# 719 2013-07-25                               Shooting     0.0       1.0
# 720 2013-07-26                                   Bomb     8.0      48.0
# 721 2013-07-26   Assassination, car bomb, other bombs     1.0       1.0
# 722 2013-07-27                     Suicide truck bomb     6.0       9.0
# 723 2013-07-27                                  Bombs     NaN       1.0
# 724 2013-07-28                       Suicide car bomb     8.0       9.0
# 725 2013-07-29                    Car and other bombs    36.0     176.0
# 726 2013-07-29                    Car and other bombs    10.0       NaN
# 727 2013-07-29                                   Raid    12.0       8.0
# 728 2013-07-30                               Car bomb     1.0       NaN
# 729 2013-07-30                  Suicide bomb and bomb     9.0      11.0
# 730 2013-08-02                   Ambush and firefight    38.0       NaN
# 731 2013-08-03            Bombings, ambush, shootings    18.0      11.0
# 732 2013-08-03                           Suicide bomb     9.0      22.0
# 733 2013-08-04                                   Bomb     0.0       3.0
# 734 2013-08-04                               Shooting     1.0       NaN
# 735 2013-08-05                                   Bomb     3.0      12.0
# 736 2013-08-05                           Vehicle bomb     6.0      29.0
# 737 2013-08-05                                 Ambush     6.0       0.0
# 738 2013-08-08                                   Bomb    10.0       3.0
# 739 2013-08-08                              Car bombs    32.0      78.0
# 740 2013-08-08                           Suicide bomb    37.0      50.0
# 741 2013-08-09                          Raid/shooting    10.0      30.0
# 742 2013-08-10      Bombings, shootings, suicide bomb    91.0     300.0
# 743 2013-08-10                                   Raid     9.0       NaN
# 744 2013-08-11                               Shooting     2.0       1.0
# 745 2013-08-10                              Shootings    56.0       NaN
# 746 2013-08-10                                Missile     0.0       NaN
# 747 2013-08-14                           Car bombings    14.0      26.0
# 748 2013-08-14                              Firefight     2.0       0.0
# 749 2013-08-15                            Car bombing    20.0     200.0
# 750 2013-08-16                         Shooting, bomb    18.0       3.0
# 751 2013-08-17                                   Bomb     0.0       0.0
# 752 2013-08-19                                 Ambush    24.0       3.0
# 753 2013-08-20                 Car bombings, bombings    10.0      81.0
# 754 2013-08-21                        Chemical attack   281.0       3.0
# 755 2013-08-24                               Bombings     1.0       2.0
# 756 2013-09-07           Car Bombing, suicide-bombing    30.0      50.0
# 757 2013-09-09      Clashes, arson and hostage-taking   220.0     254.0
# 758 2013-09-12                                Clashes     NaN       NaN
# 759 2013-09-13                   Truck bomb, shooting     2.0      20.0
# 760 2013-09-19                       Ambush, Shooting     1.0       2.0
# 761 2013-09-20  Car bombing, suicide-bombing, clashes    38.0       NaN
# 762 2013-09-21                               Shooting    68.0     100.0
# 763 2013-09-23                                Bombing     2.0       NaN
# 764 2013-09-23                Clashes, hostage-taking    10.0       NaN
# 765 2013-09-24                       Suicide bombings    85.0     100.0
# 766 2013-10-02                         Hostage-taking    24.0       5.0
#
#                                               location              city  \
# 712                                        across Iraq           Unknown
# 713                                     Abaji, Nigeria             Abaji
# 714                                   Arauca, Colombia            Arauca
# 715          Kirkuk, Taiji, Basmaiya and Baghdad, Iraq            Kirkuk
# 716                          Abu Ghraib and Taji, Iraq        Abu Ghraib
# 717                                      Sana'a, Yemen            Sana'A
# 718                                Wardak, Afghanistan            Wardak
# 719                          Derbent, Dagestan, Russia           Derbent
# 720                        Cagayan de Oro, Philippines    Cagayan De Oro
# 721                            Benghazi/Tripoli, Libya          Benghazi
# 722                                 Mogadishu, Somalia         Mogadishu
# 723                                    Benghazi, Libya          Benghazi
# 724                                 Tuz Khurmatu, Iraq      Tuz Khurmatu
# 725                 Baghdad/Basra/Kut/Mahmoudiya, Iraq           Baghdad
# 726                                      Kano, Nigeria              Kano
# 727                         Dera Ismail Khan, Pakistan  Dera Ismail Khan
# 728                                    Qamishli, Syria          Qamishli
# 729                                      Baghdad, Iraq           Baghdad
# 730           Sherzad district, Nangarhar, Afghanistan           Sherzad
# 731   Adeim,\nBaqouba,\nMosul,\nTikrit,\nBaghdad, Iraq             Adeim
# 732                             Jalalabad, Afghanistan         Jalalabad
# 733                                 Jakarta, Indonesia           Jakarta
# 734                                   Dagestan, Russia          Dagestan
# 735                           Toba Tek Singh, Pakistan    Toba Tek Singh
# 736                              Cotabato, Philippines          Cotabato
# 737                             Poonch district, India            Poonch
# 738                             Nangarhar, Afghanistan         Nangarhar
# 739                                      Baghdad, Iraq           Baghdad
# 740                                   Quetta, Pakistan            Quetta
# 741                         Quetta/Islamabad, Pakistan            Quetta
# 742  Babil, Nineveh, Baghdad, Tuz Khurmatu, Kirkuk,...             Babil
# 743                        Sheikh Zuwaid, Sinai, Egypt     Sheikh Zuwaid
# 744                                    Labweh, Lebanon            Labweh
# 745                              Konduga/Ngom, Nigeria           Konduga
# 746                                      Eilat, Israel             Eilat
# 747                                       Baquba, Iraq            Baquba
# 748                       Mubi, Adamawa state, Nigeria              Mubi
# 749                                    Beirut, Lebanon            Beirut
# 750          Karukh district/Helmand province, Lebanon            Karukh
# 751                                    Benghazi, Libya          Benghazi
# 752                           near Rafah, Sinai, Egypt             Rafah
# 753  Iskandariya,\nAmara,\nNasiriyah,\nHadhar,\nFat...       Iskandariya
# 754                                      Ghouta, Syria            Ghouta
# 755                                Ghazni, Afghanistan            Ghazni
# 756                                 Mogadishu, Somalia         Mogadishu
# 757                        Zamboanga City, Philippines    Zamboanga City
# 758                      Lamitan, Basilan, Philippines           Lamitan
# 759                                 Herat, Afghanistan             Herat
# 760                                     Zvecan, Kosovo            Zvecan
# 761                                      Shabwa, Yemen            Shabwa
# 762                                     Nairobi, Kenya           Nairobi
# 763                                        Afghanistan           Unknown
# 764              Midsayap, North Cotabato, Philippines          Midsayap
# 765                                 Peshawar, Pakistan          Peshawar
# 766  Gajiram village and Bulabulin-Nngabura village...   Gajiram Village
#
#          country
# 712         Iraq
# 713      Nigeria
# 714     Colombia
# 715         Iraq
# 716         Iraq
# 717        Yemen
# 718  Afghanistan
# 719       Russia
# 720  Philippines
# 721        Libya
# 722      Somalia
# 723        Libya
# 724         Iraq
# 725         Iraq
# 726      Nigeria
# 727     Pakistan
# 728        Syria
# 729         Iraq
# 730  Afghanistan
# 731         Iraq
# 732  Afghanistan
# 733    Indonesia
# 734       Russia
# 735     Pakistan
# 736  Philippines
# 737        India
# 738  Afghanistan
# 739         Iraq
# 740     Pakistan
# 741     Pakistan
# 742         Iraq
# 743        Egypt
# 744      Lebanon
# 745      Nigeria
# 746       Israel
# 747         Iraq
# 748      Nigeria
# 749      Lebanon
# 750      Lebanon
# 751        Libya
# 752        Egypt
# 753         Iraq
# 754        Syria
# 755  Afghanistan
# 756      Somalia
# 757  Philippines
# 758  Philippines
# 759  Afghanistan
# 760       Kosovo
# 761        Yemen
# 762        Kenya
# 763  Afghanistan
# 764  Philippines
# 765     Pakistan
# 766      Nigeria

# %%
compare_(202089, 901)
# Out:
# @tintin1957 to stop mass execution in #egypt529 plz sign this petition on avaaz
# ------------------------------------
# date                                       2014-04-01 04:15:51
# content      @tintin1957 to stop mass execution in #egypt52...
# retweet                                                  False
# frequency                                                    1
# Name: 202089, dtype: object
# ------------------------------------
# date        2014-03-14 00:00:00
# type            Suicide bombing
# deaths                        9
# injuries                     43
# location     Northwest Pakistan
# city                    Unknown
# country                Pakistan
# Name: 901, dtype: object

# %%
print("Sliding time window: 5 days ->  0.7767729652546407% of drop on 2101 Tweeets")
print("Sliding time window: 15 days -> 0.7425035697287006% of drop on 2101 Tweeets")
print("Sliding time window: 30 days -> 0.7429795335554498% of drop on 2101 Tweeets")
print("Sliding time window: 60 days -> 0.7134697762970015% of drop on 2101 Tweeets")
print("Sliding time window: 90 days -> 0.7101380295097572% of drop on 2101 Tweeets")
print("Sliding time window: 120 days-> 0.7091861018562590% of drop on 2101 Tweeets")
print("Sliding time window: 400 days-> 0.6982389338410281% of drop on 2101 Tweeets")
#str(len(tu[tu['related_attack']==-1])/len(tu))
# Out:
# Sliding time window: 5 days ->  0.7767729652546407% of drop on 2101 Tweeets
# Sliding time window: 15 days -> 0.7425035697287006% of drop on 2101 Tweeets
# Sliding time window: 30 days -> 0.7429795335554498% of drop on 2101 Tweeets
# Sliding time window: 60 days -> 0.7134697762970015% of drop on 2101 Tweeets
# Sliding time window: 90 days -> 0.7101380295097572% of drop on 2101 Tweeets
# Sliding time window: 120 days-> 0.7091861018562590% of drop on 2101 Tweeets
# Sliding time window: 400 days-> 0.6982389338410281% of drop on 2101 Tweeets

# %%
compare_(200097, 901)
# Out:
# #tu_sipelea somali suicide bomber kills self: in somalia, a suicide bomber kills only himself in a... #tu_sipelea
# ------------------------------------
# date                                       2014-03-15 12:58:14
# content      #tu_sipelea somali suicide bomber kills self: ...
# retweet                                                  False
# frequency                                                    1
# Name: 200097, dtype: object
# ------------------------------------
# date        2014-03-14 00:00:00
# type            Suicide bombing
# deaths                        9
# injuries                     43
# location     Northwest Pakistan
# city                    Unknown
# country                Pakistan
# Name: 901, dtype: object

# %%
def compare_(nb_tweet, nb_terr):

    print(tweets.loc[nb_tweet]["content"])
    print("------------------------------------")
    print(tweets.loc[nb_tweet])
    print("------------------------------------")
    print(terror.loc[nb_terr])

# %%
def expand_with_attacks(terror, index):
    
    attack = terror.loc[index]
    
    return attack["city"], attack["country"], attack["deaths"], attack["injuries"] , attack["type"]
    


tweet_terr = tu.copy()
tweet_terr = tweet_terr[tweet_terr["related_attack"]!= -1]
terr_features = tweet_terr["related_attack"].map(lambda index : expand_with_attacks(terror, index) ).apply(pd.Series)

tweet_terr['city'] = terr_features[0]
tweet_terr['country'] = terr_features[1]
tweet_terr['deaths'] = terr_features[2]
tweet_terr['injuries'] = terr_features[3]
tweet_terr['type'] = terr_features[4]

# %%
tweet_terr.groupby("city").sum()["frequency"].sort_values(ascending = False)
# Out:
# city
# Cairo        8
# Quetta       6
# Unknown      3
# Mogadishu    2
# Baghdad      2
# Musa Qala    1
# Name: frequency, dtype: int64

# %%
compare_(200100,762)
# Out:
# kenyan police must stop another terror attack in nairobi on monthly budget of $735: if kenyan security officia...
# ------------------------------------
# date                                       2014-03-15 13:07:05
# content      kenyan police must stop another terror attack ...
# retweet                                                  False
# frequency                                                    1
# Name: 200100, dtype: object
# ------------------------------------
# date        2013-09-21 00:00:00
# type                   Shooting
# deaths                       68
# injuries                    100
# city                    Nairobi
# country                   Kenya
# Name: 762, dtype: object

# %%
terror[]

# %%
print(tweets.loc[300074]["content"])
tweets.loc[300074]
# Out:
# 43 people killed in terrorist attack yesterday in lebanon. and syria where more than 100 people are killed in terro
# date                                       2015-11-14 19:39:05
# content      43 people killed in terrorist attack yesterday...
# retweet                                                   True
# frequency                                                    3
# Name: 300074, dtype: object

# %%
terror.loc[138]
# Out:
# date                2011-04-12 00:00:00
# type        Targeted killings/Shootings
# deaths                               18
# injuries                              0
# city                            Karachi
# country                        Pakistan
# Name: 138, dtype: object

# %%
tweets.groupby("related_attack").sum()["frequency"]

# %% [markdown]
# ### 3.1 Create new DataFrame with Tweets and Wiki data

# %% [markdown]
# Create DF : **date, attack type, city, country, real impact, deads, injured, social impact, number of tweets**
#
# - to merge both : match with date of event, and maybe a function that gives a matching score (name of town, country)
# - take into account the tweets from the date to a certain amount of days

# %% [markdown]
# Remark: Assumption: Each tweet correspond to one Attack identified by the index number

# %% [markdown]
# ### 3.2 Plot the attacks in a map

# %% [markdown]
# - highlight the real impacts and the social impact
# - folium ? ideally, map with circles for real impact, and (also circle ?) for social impacts

# %% [markdown]
# ### 3.3 Other graphs/info

# %% [markdown]
# - all the #prayfor : list the different towns
# - number of attacks/deaths by country (only taken from **Wikipedia dataset**)
# - ranking of the most liked/ignored attack (just divide social impact by real impact)
# - same but with country (aggregate social and total impact from before (more relevant than previous point)
# - maybe see the rise of ISIS ? find by keyword (ISIS) and check with the timeline (graph ISIS claimed vs time, **Wikipedia dataset**)
# - finally, see the fading of reactions over time

# %% [markdown]
# #### 3.3.2 Safety ranking

# %%
import matplotlib.pyplot as plt
import seaborn as sns
    
    
    
def bar_plot(data, title, y, x='', rotation=0, sort=False, ascending=True):
    fig, ax = plt.subplots()
    ax.set_title(title, fontsize=15, fontweight='bold')
    if sort:
        ax = sns.barplot(data.sort_values([y], ascending=ascending)[y].keys(), data.sort_values([y], ascending=ascending)[y], ax=ax)
    else:
        ax = sns.barplot(data[y].keys(), data[y], ax=ax)
    locs, labels = plt.xticks()
    ax.set(xlabel=x, ylabel=y)
    plt.setp(labels, rotation=rotation)
    plt.show()

# %% [markdown]
# We will now perform a ranking of the most unsafe cities and countries. By doing so, we hope to highlight the parts of the world where terrorism can be an everyday worry.

# %%
#def get_city(location):
 #   if ',' in location :
  #      city = location.split(', ',1)[0]
   #     return city
    #else : 
     #   return float('NaN')
    
#def get_country(location):
 #   if ',' in location :
  #      country = location.split(', ')[-1]
   #     return country
    #else : 
     #   return location

# %% [markdown]
# **We will now classify every city according to their number of terror attacks, and casualties :**
#
# To do so, we will create a DataFrame containing cities and their respective rankings by number of events, and casualties.

# %%
most_dangerous_cities = terror.groupby('city')['city'].count().sort_values(ascending=False)
most_dangerous_cities2 = terror.groupby('city').sum()['deaths'].dropna().sort_values(ascending=False)

cities = most_dangerous_cities.to_frame()
cities.columns = ['events']
cities['rank_event'] = range(1,len(cities.index)+1)
cities = cities.reset_index()
cities2 = most_dangerous_cities2.to_frame()
cities2.columns = ['casualties']
cities2['rank_casualties'] = range(1,len(cities2.index)+1)
cities2 = cities2.reset_index()
mg = cities.merge(cities2, on='city').iloc[:20] # We select the cities that are the most affected
mg = mg.set_index('city')
mg = mg.drop('Unknown') # drop the events with no city in the wikipedia database
mg

# attention iraq != across iraq
# Out:
#                   events  rank_event  casualties  rank_casualties
# city
# Baghdad              100           1      1613.0                3
# Kabul                 48           3       406.0               10
# Peshawar              38           4       860.0                4
# Mogadishu             38           5       417.0                9
# Maiduguri             25           6       789.0                5
# Karachi               20           7       322.0               13
# Damascus              18           8       429.0                8
# Quetta                17           9       341.0               11
# North Waziristan      15          10       153.0               27
# Sana'a                14          11       502.0                7
# Cairo                 13          12        20.0              226
# Jalalabad             12          13       166.0               25
# Jerusalem             12          14        12.0              339
# Kandahar              11          15       154.0               26
# Aden                  11          16        73.0               65
# Hangu                 10          17       118.0               36
# Mosul                  9          18        83.0               55
# Beirut                 9          19        96.0               45
# Tikrit                 9          20       247.0               17

# %% [markdown]
# As a result, **Baghdad** the most dangerous place on earth in terms of number of terror attacks, and second in terms of casualties. With 358 attacks during the studient period, it is more than three times more than the second most hit city, Mogadishu.
#
# Our study period goes from January 2011 to January 2016, which makes it around **one attack every five days**.
#
# Even though Baghdad has been covered by the Western Media during the Iraqi war with the intervention of the USA, one might be surprised by the other members of the most hit cities, such as Maiduguri, Quetta, Peshawar.

# %%
bar_plot(mg,'Most dangerous cities by number of events', 'events', rotation=90, sort=True, ascending=False)

# %% [markdown]
# **The number of events is for sure significant, but to complete our viewpoint, we will plot the same ranking by number of casualties :**

# %%
bar_plot(mg,'Most dangerous cities by casualties', 'casualties', rotation=90, sort=True, ascending=False)

# %% [markdown]
# Mosul registered 109 events, for a death toll of 3396 : an attack makes on average more than 30 victims, a sad finding of the every-day reality that happens far-away from our safe houses !

# %%
most_dangerous_countries = terror.groupby('country')['country'].count().sort_values(ascending=False)
most_dangerous_countries2 = terror.groupby('country').sum()['deaths'].dropna().sort_values(ascending=False)

countries = most_dangerous_countries.to_frame()
countries.columns = ['events']
countries['rank_event'] = range(1,len(countries.index)+1)
countries = countries.reset_index()
countries2 = most_dangerous_countries2.to_frame()
countries2.columns = ['casualties']
countries2['rank_casualties'] = range(1,len(countries2.index)+1)
countries2 = countries2.reset_index()
mgc = countries.merge(countries2, on='country') # We select the cities that are the most affected
mgc = mgc.set_index('country')

# %% [markdown]
# Iraq tops the list, and to illustrate the gap between the first few countries and the others, we will now introduce our final plot for this section, the rank by percentage of casualties :

# %%
total_cas = mgc['casualties'].sum()
mgc['per_casualties']=mgc['casualties'].map(lambda x: 100*x/total_cas)

s = mgc.iloc[:6]['per_casualties'].sum()
others = 100-s
percentage = mgc['per_casualties'].iloc[:6].append(pd.Series({'Rest of the world':others}))
percentage.rename("").plot.pie(figsize=(8,8), title='Percentage of victims of terrorism by country')
plt.show()

# %% [markdown]
# In this astonishing ranking, we can highlight two important facts :
#
# - The first **6 countries** of the list gather **more than 70%** of all deaths by terror attacks, and the other 30% are shared between all the other (around 200) countries.
# - The first European country in the list is France in 33th position. We can already imagine, before analyzing the social impact of those attacks, that this country has seen a much bigger social impact on the reactions to attacks, than most of the first 30 most hit countries.

# %% [markdown]
# ### 3.3.3 Rise of ISIS
# Avec la partie 3.2 et 3.3, on devrait avoir assez d'info a leur montrer !
#
# Et si on galère niveau temps, on se replie sur displayer des trucs sur le dataset wikipedia !

# %% [markdown]
# ## 4. Do the report
